# %% [markdown]
# The goal of this convolutional neural network is to be able to return slope of linear lines.
#
# This is because the current convolutional network essentially "draws" what a normal tau graph might look like, using the training sets to refine this drawing, instead of actually analyzing the data. This is shown when inputting linear functions or the heavyside function as flux and getting the exact same result. We'll be trying to get different results here with slope.

# %%
import torch
from torch.autograd import Variable
import torch.nn.functional as F
import torch.utils.data as Data

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import imageio

# %%
def createTrainer(num):
    lines = torch.zeros(num,1,100)
    slopes = torch.rand((num))
    slopes = slopes/2
    for i in range(num):
        lines[i,0] = torch.linspace(0,slopes[i], 100)
    return lines, slopes

ins, outs = createTrainer(100)
print(ins)
print(outs)
# Out:
# tensor([[[0.0000e+00, 1.6855e-03, 3.3710e-03,  ..., 1.6349e-01,
#           1.6518e-01, 1.6686e-01]],
#
#         [[0.0000e+00, 4.1842e-03, 8.3685e-03,  ..., 4.0587e-01,
#           4.1006e-01, 4.1424e-01]],
#
#         [[0.0000e+00, 9.2528e-04, 1.8506e-03,  ..., 8.9752e-02,
#           9.0678e-02, 9.1603e-02]],
#
#         ...,
#
#         [[0.0000e+00, 3.9080e-04, 7.8161e-04,  ..., 3.7908e-02,
#           3.8299e-02, 3.8689e-02]],
#
#         [[0.0000e+00, 4.4220e-03, 8.8441e-03,  ..., 4.2894e-01,
#           4.3336e-01, 4.3778e-01]],
#
#         [[0.0000e+00, 3.8602e-03, 7.7204e-03,  ..., 3.7444e-01,
#           3.7830e-01, 3.8216e-01]]])
# tensor([1.6686e-01, 4.1424e-01, 9.1603e-02, 1.0106e-01, 3.1559e-01, 1.3339e-01,
#         3.9167e-01, 8.8140e-02, 8.6838e-02, 4.3633e-01, 2.6637e-04, 2.7829e-01,
#         4.1075e-01, 1.4559e-01, 2.9084e-02, 4.1920e-01, 3.6381e-01, 2.0573e-01,
#         2.4063e-01, 2.4231e-01, 4.4243e-01, 2.2153e-01, 3.7508e-01, 3.1860e-01,
#         4.1089e-02, 4.4444e-01, 2.5683e-01, 2.7984e-01, 4.8695e-01, 6.5947e-02,
#         3.5472e-01, 1.2867e-01, 1.4922e-01, 4.4160e-01, 1.6901e-01, 4.9817e-01,
#         1.5294e-01, 1.3082e-01, 4.1617e-01, 4.9703e-01, 2.5355e-01, 4.4642e-01,
#         1.5909e-01, 4.3724e-01, 2.4442e-01, 4.2481e-01, 1.9886e-01, 4.1671e-01,
#         3.4091e-01, 2.1650e-01, 1.7237e-01, 4.8195e-01, 1.4652e-01, 2.2803e-01,
#         2.3709e-01, 4.0578e-01, 6.8730e-02, 3.1242e-01, 1.6270e-01, 4.4105e-01,
#         1.4915e-01, 2.2947e-01, 3.2912e-01, 3.9034e-01, 1.4484e-01, 1.0060e-01,
#         1.9692e-01, 2.7667e-01, 3.5878e-01, 1.5022e-01, 3.9519e-01, 1.7951e-02,
#         2.7050e-01, 4.1311e-01, 3.1287e-01, 3.3638e-01, 3.8236e-01, 4.5601e-01,
#         3.2650e-01, 3.5882e-01, 4.2736e-01, 4.6931e-01, 1.1211e-01, 1.9203e-01,
#         4.0499e-01, 3.0179e-01, 2.5167e-01, 2.4632e-01, 2.8502e-01, 4.9916e-01,
#         2.8360e-01, 1.3721e-01, 3.5315e-01, 5.9403e-02, 2.4036e-01, 4.0462e-01,
#         1.3716e-01, 3.8689e-02, 4.3778e-01, 3.8216e-01])

# %%
# this is one way to define a network
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.hidden1 = torch.nn.Conv1d(1, 2, 5)   # hidden layer
        self.pool1 = torch.nn.MaxPool1d(5,stride = 1)
        self.hidden2 = torch.nn.Conv1d(2,1,1)
        self.hidden3 = torch.nn.Linear(92,10)
        self.predict = torch.nn.Linear(10, 1)   # output layer
        self.oldPrediction = torch.zeros(512)

    def forward(self, x):
#         IT IS NOT AN ISSUE WITH PASSING THE INFORMATION IN
#         plt.figure()
#         plt.plot(x.reshape(-1).detach())
#         plt.show()
        print(x.shape)
        x = F.relu(self.hidden1(x)) # activation function for hidden layer
        x = self.pool1(x)
        x = F.relu(self.hidden2(x))
        x = F.relu(self.hidden3(x))
        x = self.predict(x)             # linear output
        x = x.reshape(-1)
        return x

# net = Net(n_feature=1, n_hidden=10, n_output=1)     # define the network
net = Net()
# print(net)  # net architecture
# optimizer = torch.optim.SGD(net.parameters(), lr=0.2)
optimizer = torch.optim.Adam( net.parameters(), lr=0.002, weight_decay=0.0005 )
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 50, gamma=1)
loss_func = torch.nn.MSELoss()  # this is for regression mean squared loss
my_images = []
fig, ax = plt.subplots(figsize=(12,7))

# totalTrainLoss = torch.zeros(1000)
# totalTestLoss = torch.zeros(1000)
# predictedMean = torch.zeros(1000)
# tauredMean = torch.zeros(1000)
predictions = torch.zeros(100)


# train the network
for t in range(100):
#     randomIndex = np.random.randint(0,high=len(taured)-1)
    y, x = createTrainer(100)
#     print(y.shape)
#     print(x.shape)
    prediction = net(y)     # input x and predict based on x
    loss = loss_func(prediction, x)     # must be (1. nn output, 2. target)

    optimizer.zero_grad()   # clear gradients for next train
    loss.backward()         # backpropagation, compute gradients
    optimizer.step()        # apply gradients
    scheduler.step()        # scheduler decreases learning rate geometrically every n epochs
#     predictions[t] = prediction
    
#     testLoss = validate()
#     totalTrainLoss[t] = loss
#     totalTestLoss[t] = testLoss
#     predictedMean[t] = prediction.mean()
#     tauredMean[t] = x.mean()
    
    print("Epoch = ", t)
    print("Training Loss = ", loss)
#     print("Test Loss = ", testLoss)
    
    # plot and show learning process
#     plt.cla()
#     ax.set_title('Regression Analysis', fontsize=35)
#     ax.set_xlabel('', fontsize=24)
#     ax.set_ylabel('Tau', fontsize=24)
#     ax.plot(x.data.numpy(), "r.")
#     ax.plot(prediction.data.numpy(), 'g.', lw=3)
#     ax.text(0.6, 0.8, 'Step = %d' % t, fontdict={'size': 24, 'color':  'red'})
#     ax.text(0.6, 0.7, 'Loss = %.4f' % loss.data.numpy(),
#             fontdict={'size': 24, 'color':  'red'})
    
#     ax.set_xlim(0,1.0)
#     ax.set_ylim(0,1.0)

    # Used to return the plot as an image array 
    # (https://ndres.me/post/matplotlib-animated-gifs-easily/)
#     fig.canvas.draw()       # draw the canvas, cache the renderer
#     image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
#     image  = image.reshape(fig.canvas.get_width_height()[::-1] + (3,))

#     my_images.append(image)
    
   


# # save images as a gif    
# imageio.mimsave('./linear_prediction.gif', my_images, fps=10)
# Out:
# torch.Size([100, 1, 100])
# Epoch =  0
# Training Loss =  tensor(0.0334, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  1
# Training Loss =  tensor(0.0172, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  2
# Training Loss =  tensor(0.0266, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  3
# Training Loss =  tensor(0.0226, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  4
# Training Loss =  tensor(0.0200, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  5
# Training Loss =  tensor(0.0195, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  6
# Training Loss =  tensor(0.0184, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  7
# Training Loss =  tensor(0.0166, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  8
# Training Loss =  tensor(0.0228, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  9
# Training Loss =  tensor(0.0173, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  10
# Training Loss =  tensor(0.0161, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  11
# Training Loss =  tensor(0.0188, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  12
# Training Loss =  tensor(0.0201, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  13
# Training Loss =  tensor(0.0184, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  14
# Training Loss =  tensor(0.0198, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  15
# Training Loss =  tensor(0.0196, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  16
# Training Loss =  tensor(0.0147, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  17
# Training Loss =  tensor(0.0169, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  18
# Training Loss =  tensor(0.0170, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  19
# Training Loss =  tensor(0.0166, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  20
# Training Loss =  tensor(0.0167, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  21
# Training Loss =  tensor(0.0141, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  22
# Training Loss =  tensor(0.0174, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  23
# Training Loss =  tensor(0.0175, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  24
# Training Loss =  tensor(0.0165, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  25
# Training Loss =  tensor(0.0154, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  26
# Training Loss =  tensor(0.0145, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  27
# Training Loss =  tensor(0.0160, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  28
# Training Loss =  tensor(0.0166, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  29
# Training Loss =  tensor(0.0157, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  30
# Training Loss =  tensor(0.0143, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  31
# Training Loss =  tensor(0.0143, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  32
# Training Loss =  tensor(0.0155, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  33
# Training Loss =  tensor(0.0157, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  34
# Training Loss =  tensor(0.0154, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  35
# Training Loss =  tensor(0.0164, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  36
# Training Loss =  tensor(0.0156, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  37
# Training Loss =  tensor(0.0168, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  38
# Training Loss =  tensor(0.0156, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  39
# Training Loss =  tensor(0.0161, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  40
# Training Loss =  tensor(0.0131, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  41
# Training Loss =  tensor(0.0151, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  42
# Training Loss =  tensor(0.0125, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  43
# Training Loss =  tensor(0.0127, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  44
# Training Loss =  tensor(0.0113, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  45
# Training Loss =  tensor(0.0150, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  46
# Training Loss =  tensor(0.0118, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  47
# Training Loss =  tensor(0.0123, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  48
# Training Loss =  tensor(0.0134, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  49
# Training Loss =  tensor(0.0126, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  50
# Training Loss =  tensor(0.0130, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  51
# Training Loss =  tensor(0.0122, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  52
# Training Loss =  tensor(0.0122, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  53
# Training Loss =  tensor(0.0100, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  54
# Training Loss =  tensor(0.0104, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  55
# Training Loss =  tensor(0.0107, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  56
# Training Loss =  tensor(0.0110, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  57
# Training Loss =  tensor(0.0100, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  58
# Training Loss =  tensor(0.0092, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  59
# Training Loss =  tensor(0.0101, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  60
# Training Loss =  tensor(0.0089, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  61
# Training Loss =  tensor(0.0081, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  62
# Training Loss =  tensor(0.0094, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  63
# Training Loss =  tensor(0.0066, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  64
# Training Loss =  tensor(0.0066, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  65
# Training Loss =  tensor(0.0073, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  66
# Training Loss =  tensor(0.0068, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  67
# Training Loss =  tensor(0.0063, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  68
# Training Loss =  tensor(0.0062, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  69
# Training Loss =  tensor(0.0057, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  70
# Training Loss =  tensor(0.0051, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  71
# Training Loss =  tensor(0.0054, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  72
# Training Loss =  tensor(0.0050, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  73
# Training Loss =  tensor(0.0036, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  74
# Training Loss =  tensor(0.0043, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  75
# Training Loss =  tensor(0.0040, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  76
# Training Loss =  tensor(0.0034, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  77
# Training Loss =  tensor(0.0032, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  78
# Training Loss =  tensor(0.0034, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  79
# Training Loss =  tensor(0.0021, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  80
# Training Loss =  tensor(0.0023, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  81
# Training Loss =  tensor(0.0018, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  82
# Training Loss =  tensor(0.0017, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  83
# Training Loss =  tensor(0.0015, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  84
# Training Loss =  tensor(0.0012, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  85
# Training Loss =  tensor(0.0013, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  86
# Training Loss =  tensor(0.0010, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  87
# Training Loss =  tensor(0.0007, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  88
# Training Loss =  tensor(0.0006, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  89
# Training Loss =  tensor(0.0006, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  90
# Training Loss =  tensor(0.0006, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  91
# Training Loss =  tensor(0.0004, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  92
# Training Loss =  tensor(0.0003, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  93
# Training Loss =  tensor(0.0003, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  94
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  95
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  96
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  97
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  98
# Training Loss =  tensor(0.0001, grad_fn=<MseLossBackward>)
# torch.Size([100, 1, 100])
# Epoch =  99
# Training Loss =  tensor(0.0001, grad_fn=<MseLossBackward>)

# %%
net.eval()
with torch.no_grad():
    for i in range(3):
        y,x = createTrainer(100)
        prediction = net(y)
        plt.figure()
        plt.plot(prediction.detach().numpy(), "r")
        plt.plot(x.detach().numpy(), "g")
    
net.train()
# Out:
# torch.Size([100, 1, 100])
# torch.Size([100, 1, 100])
# torch.Size([100, 1, 100])
# Net(
#   (hidden1): Conv1d(1, 2, kernel_size=(5,), stride=(1,))
#   (pool1): MaxPool1d(kernel_size=5, stride=1, padding=0, dilation=1, ceil_mode=False)
#   (hidden2): Conv1d(2, 1, kernel_size=(1,), stride=(1,))
#   (hidden3): Linear(in_features=92, out_features=10, bias=True)
#   (predict): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
# this is one way to define a network
class Net2(torch.nn.Module):
    def __init__(self):
        super(Net2, self).__init__()
#         self.hidden1 = torch.nn.Conv1d(1, 2, 5)   # hidden layer
#         self.pool1 = torch.nn.MaxPool1d(5,stride = 1)
#         self.hidden2 = torch.nn.Conv1d(2,1,1)
        self.hidden3 = torch.nn.Linear(100,10)
        self.predict = torch.nn.Linear(10, 1)   # output layer
        self.oldPrediction = torch.zeros(512)

    def forward(self, x):
#         IT IS NOT AN ISSUE WITH PASSING THE INFORMATION IN
#         plt.figure()
#         plt.plot(x.reshape(-1).detach())
#         plt.show()
#         x = F.relu(self.hidden1(x)) # activation function for hidden layer
#         x = self.pool1(x)
#         x = self.hidden2(x)
        x = self.hidden3(x)
        x = self.predict(x)             # linear output
        x = x.reshape(-1)
        return x

# net = Net(n_feature=1, n_hidden=10, n_output=1)     # define the network
net2 = Net2()
# print(net)  # net architecture
# optimizer = torch.optim.SGD(net.parameters(), lr=0.2)
optimizer = torch.optim.Adam( net.parameters(), lr=0.002, weight_decay=0.0005 )
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 50, gamma=1)
loss_func = torch.nn.MSELoss()  # this is for regression mean squared loss
my_images = []
fig, ax = plt.subplots(figsize=(12,7))

# totalTrainLoss = torch.zeros(1000)
# totalTestLoss = torch.zeros(1000)
# predictedMean = torch.zeros(1000)
# tauredMean = torch.zeros(1000)
predictions = torch.zeros(100)


# train the network
for t in range(100):
#     randomIndex = np.random.randint(0,high=len(taured)-1)
    y = ins[t,...]
    y = torch.reshape(y, (-1,1,100))
    prediction = net(y)     # input x and predict based on x
    loss = loss_func(prediction, outs[t])     # must be (1. nn output, 2. target)

    optimizer.zero_grad()   # clear gradients for next train
    loss.backward()         # backpropagation, compute gradients
    optimizer.step()        # apply gradients
    scheduler.step()        # scheduler decreases learning rate geometrically every n epochs
    predictions[t] = prediction
    
#     testLoss = validate()
#     totalTrainLoss[t] = loss
#     totalTestLoss[t] = testLoss
#     predictedMean[t] = prediction.mean()
#     tauredMean[t] = x.mean()
    
    print("Epoch = ", t)
    print("Training Loss = ", loss)
#     print("Test Loss = ", testLoss)
    
    # plot and show learning process
#     plt.cla()
#     ax.set_title('Regression Analysis', fontsize=35)
#     ax.set_xlabel('', fontsize=24)
#     ax.set_ylabel('Tau', fontsize=24)
#     ax.plot(x.data.numpy(), "r.")
#     ax.plot(prediction.data.numpy(), 'g.', lw=3)
#     ax.text(0.6, 0.8, 'Step = %d' % t, fontdict={'size': 24, 'color':  'red'})
#     ax.text(0.6, 0.7, 'Loss = %.4f' % loss.data.numpy(),
#             fontdict={'size': 24, 'color':  'red'})
    
#     ax.set_xlim(0,1.0)
#     ax.set_ylim(0,1.0)

    # Used to return the plot as an image array 
    # (https://ndres.me/post/matplotlib-animated-gifs-easily/)
#     fig.canvas.draw()       # draw the canvas, cache the renderer
#     image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
#     image  = image.reshape(fig.canvas.get_width_height()[::-1] + (3,))

#     my_images.append(image)
    
   


# # save images as a gif    
# imageio.mimsave('./linear_prediction.gif', my_images, fps=10)
# Out:
# torch.Size([1, 1, 100])
# Epoch =  0
# Training Loss =  tensor(3.7466e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  1
# Training Loss =  tensor(0.0102, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  2
# Training Loss =  tensor(0.0004, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  3
# Training Loss =  tensor(0.0004, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  4
# Training Loss =  tensor(0.0077, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  5
# Training Loss =  tensor(0.0024, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  6
# Training Loss =  tensor(0.0035, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  7
# Training Loss =  tensor(3.2329e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  8
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  9
# Training Loss =  tensor(0.0016, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  10
# Training Loss =  tensor(0.0015, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  11
# Training Loss =  tensor(0.0007, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  12
# Training Loss =  tensor(0.0018, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  13
# Training Loss =  tensor(0.0004, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  14
# Training Loss =  tensor(0.0004, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  15
# Training Loss =  tensor(5.1408e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  16
# Training Loss =  tensor(0.0009, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  17
# Training Loss =  tensor(0.0007, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  18
# Training Loss =  tensor(0.0009, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  19
# Training Loss =  tensor(0.0006, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  20
# Training Loss =  tensor(2.5238e-06, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  21
# Training Loss =  tensor(3.3098e-06, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  22
# Training Loss =  tensor(0.0001, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  23
# Training Loss =  tensor(9.6443e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  24
# Training Loss =  tensor(0.0006, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  25
# Training Loss =  tensor(0.0012, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  26
# Training Loss =  tensor(1.0361e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  27
# Training Loss =  tensor(5.4432e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  28
# Training Loss =  tensor(0.0003, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  29
# Training Loss =  tensor(6.8753e-09, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  30
# Training Loss =  tensor(0.0012, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  31
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  32
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  33
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  34
# Training Loss =  tensor(3.5211e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  35
# Training Loss =  tensor(0.0007, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  36
# Training Loss =  tensor(1.1445e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  37
# Training Loss =  tensor(2.9909e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  38
# Training Loss =  tensor(1.2971e-06, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  39
# Training Loss =  tensor(0.0004, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  40
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  41
# Training Loss =  tensor(7.4288e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  42
# Training Loss =  tensor(4.7354e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  43
# Training Loss =  tensor(0.0001, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  44
# Training Loss =  tensor(0.0001, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  45
# Training Loss =  tensor(1.8901e-07, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  46
# Training Loss =  tensor(1.4747e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  47
# Training Loss =  tensor(0.0001, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  48
# Training Loss =  tensor(4.8545e-06, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  49
# Training Loss =  tensor(6.2009e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  50
# Training Loss =  tensor(0.0001, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  51
# Training Loss =  tensor(0.0005, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  52
# Training Loss =  tensor(5.4922e-06, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  53
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  54
# Training Loss =  tensor(0.0004, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  55
# Training Loss =  tensor(0.0006, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  56
# Training Loss =  tensor(6.3883e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  57
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  58
# Training Loss =  tensor(8.0943e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  59
# Training Loss =  tensor(0.0003, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  60
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  61
# Training Loss =  tensor(4.4999e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  62
# Training Loss =  tensor(1.2592e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  63
# Training Loss =  tensor(3.5231e-06, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  64
# Training Loss =  tensor(3.8798e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  65
# Training Loss =  tensor(6.2919e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  66
# Training Loss =  tensor(2.6378e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  67
# Training Loss =  tensor(0.0003, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  68
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  69
# Training Loss =  tensor(1.6005e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  70
# Training Loss =  tensor(6.3259e-06, grad_fn=<MseLossBackward>)
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\loss.py:446: UserWarning: Using a target size (torch.Size([])) that is different to the input size (torch.Size([1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# torch.Size([1, 1, 100])
# Epoch =  71
# Training Loss =  tensor(0.0004, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  72
# Training Loss =  tensor(1.3637e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  73
# Training Loss =  tensor(0.0001, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  74
# Training Loss =  tensor(7.1467e-06, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  75
# Training Loss =  tensor(3.0355e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  76
# Training Loss =  tensor(4.9411e-06, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  77
# Training Loss =  tensor(0.0001, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  78
# Training Loss =  tensor(0.0001, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  79
# Training Loss =  tensor(7.9618e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  80
# Training Loss =  tensor(1.4295e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  81
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  82
# Training Loss =  tensor(4.1570e-07, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  83
# Training Loss =  tensor(6.4649e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  84
# Training Loss =  tensor(0.0001, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  85
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  86
# Training Loss =  tensor(2.0866e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  87
# Training Loss =  tensor(9.5997e-06, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  88
# Training Loss =  tensor(6.1350e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  89
# Training Loss =  tensor(0.0019, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  90
# Training Loss =  tensor(1.1712e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  91
# Training Loss =  tensor(2.6751e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  92
# Training Loss =  tensor(0.0008, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  93
# Training Loss =  tensor(1.8112e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  94
# Training Loss =  tensor(0.0003, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  95
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  96
# Training Loss =  tensor(2.3144e-05, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  97
# Training Loss =  tensor(0.0002, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  98
# Training Loss =  tensor(0.0005, grad_fn=<MseLossBackward>)
# torch.Size([1, 1, 100])
# Epoch =  99
# Training Loss =  tensor(8.5754e-05, grad_fn=<MseLossBackward>)

# %%
plt.figure()
plt.plot(outs.detach(), "g")
plt.plot(predictions.detach(), "r")
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e328e6d4c920> in <module>
#       1 plt.figure()
# ----> 2 plt.plot(outs.detach(), "g")
#       3 plt.plot(predictions.detach(), "r")
#       4 plt.show
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     269             raise ValueError("x and y must have same first dimension, but "
#     270                              "have shapes {} and {}".format(x.shape, y.shape))
# --> 271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#     273                              "shapes {} and {}".format(x.shape, y.shape))
#
# AttributeError: 'Tensor' object has no attribute 'ndim'
